# %% [markdown]
# # Yelp API - Lab
#
#
# ## Introduction
#
# We've seen how the Yelp API works and how to create basic visualizations using Folium. It's time to put those skills to work in order to create a working map! Taking things a step further, you'll also independently explore how to perform pagination in order to retrieve a full results set from the Yelp API!
#
# ## Objectives
#
# You will be able to:
#
# * Using pagination and multiple functions, gather large amounts of data from an API, parse the data and make sense of it with meaningful analysis
# * Create maps using Folium
#
# ## Problem Introduction
#
# You've now worked with some API calls, but we have yet to see how to retrieve a more complete dataset in a programmatic manner. Returning to the Yelp API, the [documentation](https://www.yelp.com/developers/documentation/v3/business_search) also provides us details regarding the API limits. These often include details about the number of requests a user is allowed to make within a specified time limit and the maximum number of results to be returned. In this case, we are told that any request has a maximum of 50 results per request and defaults to 20. Furthermore, any search will be limited to a total of 1000 results. To retrieve all 1000 of these results, we would have to page through the results piece by piece, retrieving 50 at a time. Processes such as these are often referred to as pagination.
#
# In this lab, you will define a search and then paginate over the results to retrieve all of the results. You'll then parse these responses as a DataFrame (for further exploration) and create a map using Folium to visualize the results geographically.
#
# ## Part I - Make the Initial Request
#
# Start by making an initial request to the Yelp API. Your search must include at least 2 parameters: **term** and **location**. For example, you might search for pizza restaurants in NYC. The term and location is up to you but make the request below.

# %%
import requests
import pandas as pd

# %%
url = 'https://api.yelp.com/v3/businesses/search'

client_id = 'bVX1Jsfp4dkIOqw5HOVplg'
api_key = 'RTzp-q-TgkJW_NFQogubFvZNRDziXyoR38VbtZMWibDI-FlvB25OE7GmafFEqhTL8_Bk2HlcX24-hRWLMP7Nc6WHO_VXMXldpPBjP0LoPv5EFFELMSI2oll8njhbXHYx'

term = 'chinese'
location = 'seattle'
SEARCH_LIMIT = 50

headers = {
    'Authorization': 'Bearer {}'.format(api_key),
}

url_params = {
    'term': term.replace(' ', '+'),
    'location': location.replace(' ', '+'),
    'limit': SEARCH_LIMIT
}

response = requests.get(url, headers=headers, params=url_params)

json_response = response.json()
json_response
# Out:
# {'businesses': [{'id': 'bzX2yVjfPEOBzBnZeWXQKQ',
#    'alias': 'a-hong-kong-kitchen-seattle',
#    'name': 'A + Hong Kong Kitchen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RblL425cKW-nZC3MmNh5yA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/a-hong-kong-kitchen-seattle?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 501,
#    'categories': [{'alias': 'cantonese', 'title': 'Cantonese'},
#     {'alias': 'hkcafe', 'title': 'Hong Kong Style Cafe'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.59854, 'longitude': -122.32652},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '419 6th Ave S',
#     'address2': None,
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98104',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['419 6th Ave S', 'Seattle, WA 98104']},
#    'phone': '+12066821267',
#    'display_phone': '(206) 682-1267',
#    'distance': 3063.9942704448877},
#   {'id': 'OjX2LacSZd_w2Olmx55HJA',
#    'alias': 'harbor-city-restaurant-seattle',
#    'name': 'Harbor City Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GaUSvXGfs9yON34kS9QIkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/harbor-city-restaurant-seattle?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 1566,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'cantonese', 'title': 'Cantonese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.59821, 'longitude': -122.32339},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '707 S King St',
#     'address2': '',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98104',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['707 S King St', 'Seattle, WA 98104']},
#    'phone': '+12066212228',
#    'display_phone': '(206) 621-2228',
#    'distance': 3155.507567452402},
#   {'id': 'jDrlINIeBl0rQol8ZQrtEQ',
#    'alias': 'zheng-cafe-seattle-3',
#    'name': 'Zheng Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bBINQKdxDEx7tTd8wP80IQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zheng-cafe-seattle-3?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 160,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.62071, 'longitude': -122.34476},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '230 6th Ave N',
#     'address2': '',
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98109',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['230 6th Ave N', 'Seattle, WA 98109']},
#    'phone': '+12065882882',
#    'display_phone': '(206) 588-2882',
#    'distance': 865.913739464457},
#   {'id': 'NCDpIDp2f-DhPO5sL5Hbdw',
#    'alias': 'xian-noodles-seattle-4',
#    'name': "Xi'an Noodles",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MErC-4Z-UX9HItR0LVKx0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/xian-noodles-seattle-4?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 782,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'hotpot', 'title': 'Hot Pot'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.66815, 'longitude': -122.31319},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '5259 University Way NE',
#     'address2': None,
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98105',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['5259 University Way NE', 'Seattle, WA 98105']},
#    'phone': '+12065228888',
#    'display_phone': '(206) 522-8888',
#    'distance': 5034.301016772765},
#   {'id': 'ZCtSkAulGzhWd1o0oWbYgQ',
#    'alias': 'din-tai-fung-seattle-14',
#    'name': 'Din Tai Fung',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fKx4S50dSx145q29hgtuIA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/din-tai-fung-seattle-14?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 1374,
#    'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'},
#     {'alias': 'shanghainese', 'title': 'Shanghainese'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.61289, 'longitude': -122.33531},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '600 Pine St',
#     'address2': 'Ste 403',
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98101',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['600 Pine St', 'Ste 403', 'Seattle, WA 98101']},
#    'phone': '+12066829888',
#    'display_phone': '(206) 682-9888',
#    'distance': 1399.1438872560698},
#   {'id': 'kjoVE8SlcwKnDtfxtfjlZA',
#    'alias': 'qin-xian-noodles-seattle-3',
#    'name': "Qin Xi'an Noodles",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/pTF4YIb3aMqcnbLrN8Msfw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/qin-xian-noodles-seattle-3?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 244,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.61488, 'longitude': -122.32839},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1203 Pine St',
#     'address2': '',
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98101',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['1203 Pine St', 'Seattle, WA 98101']},
#    'phone': '+12063320220',
#    'display_phone': '(206) 332-0220',
#    'distance': 1288.6394579562111},
#   {'id': 'MPq9DFOVsQRKSkiMjAIwug',
#    'alias': 'tian-fu-seattle-4',
#    'name': 'Tian Fu',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KQFgT4pdsx0W4yGR1-GaTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tian-fu-seattle-4?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 54,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 47.7091, 'longitude': -122.32465},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '300 NE Northgate Way',
#     'address2': None,
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98125',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['300 NE Northgate Way', 'Seattle, WA 98125']},
#    'phone': '+12063633292',
#    'display_phone': '(206) 363-3292',
#    'distance': 9297.339652646853},
#   {'id': 'hj9s0BVirRTTS4ZV_DtRtw',
#    'alias': 'sichuanese-cuisine-seattle',
#    'name': 'Sichuanese Cuisine',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UISwsNORDDtxrhlEu4rbpA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sichuanese-cuisine-seattle?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 623,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'},
#     {'alias': 'hotpot', 'title': 'Hot Pot'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.5993655520798,
#     'longitude': -122.317549573997},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1048 S Jackson St',
#     'address2': '',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98104',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['1048 S Jackson St', 'Seattle, WA 98104']},
#    'phone': '+12067201690',
#    'display_phone': '(206) 720-1690',
#    'distance': 3194.581888156946},
#   {'id': 'ySKMvcI3ImApkkMkSjna9A',
#    'alias': 'mikes-noodle-house-seattle',
#    'name': "Mike's Noodle House",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OXDzBdLlAK4AyKt4bt6u1Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mikes-noodle-house-seattle?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 1075,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.59859, 'longitude': -122.32482},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '418 Maynard Ave S',
#     'address2': '',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98104',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['418 Maynard Ave S', 'Seattle, WA 98104']},
#    'phone': '+12063897099',
#    'display_phone': '(206) 389-7099',
#    'distance': 3084.211960034711},
#   {'id': 'uHT6tk6YtCDQST9fJJOCow',
#    'alias': 'magic-dragon-seattle-3',
#    'name': 'Magic Dragon',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XdMZPRf8_-0cyPUTxfX8LA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/magic-dragon-seattle-3?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 224,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 47.63546, 'longitude': -122.37703},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1827 15th Ave W',
#     'address2': None,
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98119',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['1827 15th Ave W', 'Seattle, WA 98119']},
#    'phone': '+12062847470',
#    'display_phone': '(206) 284-7470',
#    'distance': 3305.9377318775055},
#   {'id': 'YK5eyqqIc9cq2N6QfPUJ6g',
#    'alias': 'fu-shen-seattle',
#    'name': 'Fu Shen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UebJrlahVjQA5Li1KkYqTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fu-shen-seattle?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 210,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.69473, 'longitude': -122.34492},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '9019 Aurora Ave N',
#     'address2': '',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98103',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['9019 Aurora Ave N', 'Seattle, WA 98103']},
#    'phone': '+12066243888',
#    'display_phone': '(206) 624-3888',
#    'distance': 7746.2135727258},
#   {'id': 'qLzed7jKJcJgfbhqaofLzQ',
#    'alias': 'lionhead-seattle-2',
#    'name': 'Lionhead',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sMR1cgdHs8qgO46cWF8k1g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lionhead-seattle-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 202,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.6248035549413,
#     'longitude': -122.320777901654},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '618 Broadway E',
#     'address2': '',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98102',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['618 Broadway E', 'Seattle, WA 98102']},
#    'phone': '+12069223326',
#    'display_phone': '(206) 922-3326',
#    'distance': 1106.204756457839},
#   {'id': 'nmCvyQZWEKTtmYGJDzMLEw',
#    'alias': 'chuan-on-capitol-seattle-2',
#    'name': 'Chuan On Capitol',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/eRzWhvboO2I-cx6HHvlqMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chuan-on-capitol-seattle-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 100,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'},
#     {'alias': 'hotpot', 'title': 'Hot Pot'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.613953, 'longitude': -122.324138},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '601 E Pike St',
#     'address2': 'Ste 100',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98122',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['601 E Pike St', 'Ste 100', 'Seattle, WA 98122']},
#    'phone': '+12068098999',
#    'display_phone': '(206) 809-8999',
#    'distance': 1536.5506785004218},
#   {'id': 'f0Isf3GraqzfCDKmMZ83qQ',
#    'alias': 'country-dough-seattle',
#    'name': 'Country Dough',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UPhPj2ySfM5DDsIMQrT9rQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/country-dough-seattle?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 411,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 47.61018, 'longitude': -122.34274},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1916 Pike Pl',
#     'address2': 'Ste 14',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98101',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['1916 Pike Pl', 'Ste 14', 'Seattle, WA 98101']},
#    'phone': '+12067282598',
#    'display_phone': '(206) 728-2598',
#    'distance': 1781.6956299797653},
#   {'id': 'mp3KT0jgce1_4GoFBoGB_A',
#    'alias': '19-gold-seattle',
#    'name': '19 GOLD',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OyHGbC6Rba0L3LbpyAp5KA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/19-gold-seattle?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 287,
#    'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 47.651839, 'longitude': -122.350314},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3601 Fremont Ave N',
#     'address2': 'Ste 101',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98103',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['3601 Fremont Ave N', 'Ste 101', 'Seattle, WA 98103']},
#    'phone': '+12065880952',
#    'display_phone': '(206) 588-0952',
#    'distance': 3135.618465503346},
#   {'id': '9vp47oNBP3iHTTPgrsWyNQ',
#    'alias': 'little-duck-seattle-2',
#    'name': 'Little Duck',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rPdSUtYFuMrCDAmY77HD4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-duck-seattle-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 75,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.65707, 'longitude': -122.31748},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '4100 Roosevelt Way NE',
#     'address2': 'Unit B',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98105',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['4100 Roosevelt Way NE',
#      'Unit B',
#      'Seattle, WA 98105']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3768.13565112976},
#   {'id': 'JWtrqqPxfmc3g0NPoBJV3w',
#    'alias': 'sizzling-pot-king-seattle-2',
#    'name': 'Sizzling Pot King',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/u6o85PNAJmOhhFD7gVwHPQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sizzling-pot-king-seattle-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 105,
#    'categories': [{'alias': 'hotpot', 'title': 'Hot Pot'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.5985, 'longitude': -122.32445},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '660 S King St',
#     'address2': '',
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98104',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['660 S King St', 'Seattle, WA 98104']},
#    'phone': '+12066240314',
#    'display_phone': '(206) 624-0314',
#    'distance': 3097.7551317704424},
#   {'id': 'C8ZT659Wp4cr5wLR_UDukw',
#    'alias': 'chef-liao-asian-fusion-cuisine-seattle',
#    'name': 'Chef Liao Asian Fusion Cuisine',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8zwtdoTAHpGtewQa8t011Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chef-liao-asian-fusion-cuisine-seattle?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 324,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.67299, 'longitude': -122.35418},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '6012 Phinney Ave N',
#     'address2': None,
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98103',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['6012 Phinney Ave N', 'Seattle, WA 98103']},
#    'phone': '+12067896441',
#    'display_phone': '(206) 789-6441',
#    'distance': 5460.371268530971},
#   {'id': 'fAwy6nzSBvgy7SbJJlYdDA',
#    'alias': 'spiceup-seattle-3',
#    'name': 'Spiceup',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HNa82W2wGA5hr4Or-2WPCw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spiceup-seattle-3?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 230,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 47.614831, 'longitude': -122.344332},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '305 Bell St',
#     'address2': '',
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98121',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['305 Bell St', 'Seattle, WA 98121']},
#    'phone': '+12067282551',
#    'display_phone': '(206) 728-2551',
#    'distance': 1350.2935476425164},
#   {'id': 'ug_QHgsMXDO16_lSs6ywRQ',
#    'alias': 'pacific-cafe-hong-kong-kitchen-seattle-2',
#    'name': 'Pacific Cafe Hong Kong Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/E5-aCFzDZgcgPY1Apd4F7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pacific-cafe-hong-kong-kitchen-seattle-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 259,
#    'categories': [{'alias': 'cantonese', 'title': 'Cantonese'},
#     {'alias': 'hkcafe', 'title': 'Hong Kong Style Cafe'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.59865, 'longitude': -122.32749},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '416 5th Ave S',
#     'address2': '',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98104',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['416 5th Ave S', 'Seattle, WA 98104']},
#    'phone': '+12066820908',
#    'display_phone': '(206) 682-0908',
#    'distance': 3031.3474024598263},
#   {'id': 'UUoIThvoh8wRl0ekGaYhYA',
#    'alias': 'tai-tung-chinese-restaurant-seattle',
#    'name': 'Tai Tung Chinese Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qjiEgYxvDqSKrgsXjxnUYA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tai-tung-chinese-restaurant-seattle?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 281,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.5982, 'longitude': -122.32469},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '659 S King St',
#     'address2': '',
#     'address3': 'The Rex Apartments',
#     'city': 'Seattle',
#     'zip_code': '98104',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['659 S King St',
#      'The Rex Apartments',
#      'Seattle, WA 98104']},
#    'phone': '+12066227372',
#    'display_phone': '(206) 622-7372',
#    'distance': 3128.3616739838476},
#   {'id': '0GMUVpxMjRrKk7vJO3EC8w',
#    'alias': 'king-noodle-seattle',
#    'name': 'King Noodle',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ms4wmgjnoHN-ymhA-jmIug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/king-noodle-seattle?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 567,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.5982, 'longitude': -122.32551},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '615 S King St',
#     'address2': '',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98104',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['615 S King St', 'Seattle, WA 98104']},
#    'phone': '+12067489168',
#    'display_phone': '(206) 748-9168',
#    'distance': 3111.357562618642},
#   {'id': 'qESIVKVPI-Ubz9FVNNDtiA',
#    'alias': 'hue-ky-mi-gia-seattle',
#    'name': 'Hue Ky Mi Gia',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BS-BCf672BhG22C8ozi1_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hue-ky-mi-gia-seattle?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 513,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.5990692269986,
#     'longitude': -122.316223301189},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1207 S Jackson St',
#     'address2': 'Ste 101',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98144',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['1207 S Jackson St', 'Ste 101', 'Seattle, WA 98144']},
#    'phone': '+12065681268',
#    'display_phone': '(206) 568-1268',
#    'distance': 3267.2546917383506},
#   {'id': 'ud5NuBZka9lVZdRlhQDrjQ',
#    'alias': 'din-tai-fung-seattle',
#    'name': 'Din Tai Fung',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JDwl3CKKdFaeOqjcZ36jMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/din-tai-fung-seattle?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 2124,
#    'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'},
#     {'alias': 'shanghainese', 'title': 'Shanghainese'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.66164, 'longitude': -122.29921},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '2621 NE 46th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98105',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['2621 NE 46th St', 'Seattle, WA 98105']},
#    'phone': '+12065250958',
#    'display_phone': '(206) 525-0958',
#    'distance': 4842.619248577799},
#   {'id': 'jzZatlgnWJfdTT_hY7NHLw',
#    'alias': 'taste-of-xian-seattle',
#    'name': "Taste of Xi'an",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TkINmDWAoDUKaCro3qX9vg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taste-of-xian-seattle?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 319,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.66196, 'longitude': -122.31345},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '4523 University Way NE',
#     'address2': '',
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98105',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['4523 University Way NE', 'Seattle, WA 98105']},
#    'phone': '+12062319999',
#    'display_phone': '(206) 231-9999',
#    'distance': 4390.090404546986},
#   {'id': 'mGPFMGBfu64j5KEaZO8JfQ',
#    'alias': 'mei-mei-cafe-seattle-2',
#    'name': 'Mei Mei Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mvHcPHRNgfpzUxbnlfMMEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mei-mei-cafe-seattle-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 40,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 47.66529, 'longitude': -122.31705},
#    'transactions': [],
#    'location': {'address1': '1004 NE 50th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98105',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['1004 NE 50th St', 'Seattle, WA 98105']},
#    'phone': '+12067292218',
#    'display_phone': '(206) 729-2218',
#    'distance': 4644.12619962942},
#   {'id': 'FLp-jLL5E09T_wMQMbZq2Q',
#    'alias': 'little-chengdu-seattle-2',
#    'name': 'Little Chengdu',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gPk9v6rdcBpp7s-i-iFCEQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-chengdu-seattle-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 144,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.57471, 'longitude': -122.29583},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2815 S Hanford St',
#     'address2': None,
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98144',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['2815 S Hanford St', 'Seattle, WA 98144']},
#    'phone': '+12067609263',
#    'display_phone': '(206) 760-9263',
#    'distance': 6372.595172705826},
#   {'id': 's1KxyLIx8u4ltDavPJgm_g',
#    'alias': 'dough-zone-dumpling-house-seattle-5',
#    'name': 'Dough Zone Dumpling House',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xTxwCVS7vhhyLzofCS__pg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dough-zone-dumpling-house-seattle-5?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 229,
#    'categories': [{'alias': 'shanghainese', 'title': 'Shanghainese'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.61317, 'longitude': -122.33215},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '815 Pine St',
#     'address2': '',
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98101',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['815 Pine St', 'Seattle, WA 98101']},
#    'phone': '+12066826666',
#    'display_phone': '(206) 682-6666',
#    'distance': 1386.5687092723338},
#   {'id': 'e8UiD4SOyfyv5PIB5i1EvQ',
#    'alias': 'kau-kau-barbeque-seattle',
#    'name': 'Kau Kau Barbeque',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Zc9ILEIxwPf8PhVG8SuSBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kau-kau-barbeque-seattle?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 990,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cantonese', 'title': 'Cantonese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.59847, 'longitude': -122.32471},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '656 S King St',
#     'address2': None,
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98104',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['656 S King St', 'Seattle, WA 98104']},
#    'phone': '+12066824006',
#    'display_phone': '(206) 682-4006',
#    'distance': 3094.6179439038815},
#   {'id': 'IbRT1K1TQ7mFXjlIZ9onUw',
#    'alias': 'youngs-restaurant-seattle',
#    'name': "Young's Restaurant",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pmdv0eyzIjlBjZ6v31n36A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/youngs-restaurant-seattle?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 164,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 47.51872, 'longitude': -122.35554},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '9413 16th Ave SW',
#     'address2': '',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98106',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['9413 16th Ave SW', 'Seattle, WA 98106']},
#    'phone': '+12067623438',
#    'display_phone': '(206) 762-3438',
#    'distance': 11956.925979789201},
#   {'id': '-m4Kstq6W3cUWTClqJNTyA',
#    'alias': 'chef-king-seattle-4',
#    'name': 'Chef King',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/frDi4XBGmaiqUc0lR_3LiA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chef-king-seattle-4?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 43,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.6903854, 'longitude': -122.357799},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '101 N 85th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98103',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['101 N 85th St', 'Seattle, WA 98103']},
#    'phone': '+12068299357',
#    'display_phone': '(206) 829-9357',
#    'distance': 7414.2910508102605},
#   {'id': 'rmDupSgIm6zCE6RgAKhibA',
#    'alias': 'uptown-china-restaurant-seattle',
#    'name': 'Uptown China Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nxakbirfHju4NZeRRuDXmQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/uptown-china-restaurant-seattle?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 372,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 47.61995, 'longitude': -122.3565613},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '200 Queen Anne Ave N',
#     'address2': '',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98109',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['200 Queen Anne Ave N', 'Seattle, WA 98109']},
#    'phone': '+12062857710',
#    'display_phone': '(206) 285-7710',
#    'distance': 1690.8458584978796},
#   {'id': '2Na4OIPnNZpzlG9kuonXUw',
#    'alias': 'lucky-chinese-restaurant-seattle',
#    'name': 'Lucky Chinese Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QZTVLX9Qm4Q5avu0FAh_zA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lucky-chinese-restaurant-seattle?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 105,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.55081, 'longitude': -122.32995},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '5807 4th Ave S',
#     'address2': '',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98108',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['5807 4th Ave S', 'Seattle, WA 98108']},
#    'phone': '+12067620676',
#    'display_phone': '(206) 762-0676',
#    'distance': 8306.552459405912},
#   {'id': 'X3OpfR6P4B-WODm1LMiUoQ',
#    'alias': 'regent-bakery-and-cafe-seattle',
#    'name': 'Regent Bakery & Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/64jZnvKgYkaGvJSNfjVZoQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/regent-bakery-and-cafe-seattle?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 284,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'hkcafe', 'title': 'Hong Kong Style Cafe'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.615436, 'longitude': -122.314095},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1404 E Pine St',
#     'address2': '',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98122',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['1404 E Pine St', 'Seattle, WA 98122']},
#    'phone': '+12067438866',
#    'display_phone': '(206) 743-8866',
#    'distance': 1951.5315586742097},
#   {'id': 'el6YmQ5Y4ispZQvqm-bz6w',
#    'alias': 'homestyle-dim-sum-seattle-2',
#    'name': 'Homestyle Dim Sum',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/BUZ6niuGT2JlLy_2TIYDmQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/homestyle-dim-sum-seattle-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 24,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 47.5976300583, 'longitude': -122.324270122},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '664 S Weller St',
#     'address2': None,
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98104',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['664 S Weller St', 'Seattle, WA 98104']},
#    'phone': '+12063406122',
#    'display_phone': '(206) 340-6122',
#    'distance': 3202.8110962807305},
#   {'id': 'GoWeog3TbHM6SL9dL_AnTA',
#    'alias': 'jade-garden-seattle',
#    'name': 'Jade Garden',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/BKnlM9XP1VUjDVBJIS2RxA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jade-garden-seattle?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 1432,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cantonese', 'title': 'Cantonese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 47.5985020713873,
#     'longitude': -122.323515415192},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '424 7th Ave S',
#     'address2': '',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98104',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['424 7th Ave S', 'Seattle, WA 98104']},
#    'phone': '+12066228181',
#    'display_phone': '(206) 622-8181',
#    'distance': 3125.1711177168672},
#   {'id': 'eM8Ar2FycR0k6oX__DJ_LA',
#    'alias': 'wild-ginger-seattle-5',
#    'name': 'Wild Ginger',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/msde8Row58yUrFCSYcYvog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wild-ginger-seattle-5?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 74,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.6174752, 'longitude': -122.3392648},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2202B 8th Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98121',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['2202B 8th Ave', 'Seattle, WA 98121']},
#    'phone': '+12067070396',
#    'display_phone': '(206) 707-0396',
#    'distance': 920.3676650430095},
#   {'id': 'yNHvaGHci6sfF_ayn40KnQ',
#    'alias': 'julies-garden-seattle',
#    'name': "Julie's Garden",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yk7BfO7PUayAQy7CupK0sw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/julies-garden-seattle?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 183,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.601566, 'longitude': -122.3351543},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '81 Yesler Way',
#     'address2': '',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98104',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['81 Yesler Way', 'Seattle, WA 98104']},
#    'phone': '+12062233690',
#    'display_phone': '(206) 223-3690',
#    'distance': 2652.469143144949},
#   {'id': 'cDoFLe0IU1uc7CCPpje0oA',
#    'alias': 'chengdu-memory-seattle',
#    'name': 'Chengdu Memory',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TsNwzez5AD1H1EAfvJTqhQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chengdu-memory-seattle?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 116,
#    'categories': [{'alias': 'hotpot', 'title': 'Hot Pot'},
#     {'alias': 'szechuan', 'title': 'Szechuan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.599369, 'longitude': -122.326621},
#    'transactions': [],
#    'location': {'address1': '520 S Jackson St',
#     'address2': None,
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98104',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['520 S Jackson St', 'Seattle, WA 98104']},
#    'phone': '+12066246289',
#    'display_phone': '(206) 624-6289',
#    'distance': 2972.7091503367074},
#   {'id': 'pjxLWC1XqPGAdPxZupJgBg',
#    'alias': 'mee-sum-pastry-seattle',
#    'name': 'Mee Sum Pastry',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/du7lzcATANXwsKcAJqxTSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mee-sum-pastry-seattle?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 777,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.6091726957566,
#     'longitude': -122.341359799475},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1526 Pike Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98101',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['1526 Pike Pl', 'Seattle, WA 98101']},
#    'phone': '+12066826780',
#    'display_phone': '(206) 682-6780',
#    'distance': 1858.9551655891842},
#   {'id': '5syT0YMV8UbcUOFVokrpRg',
#    'alias': 'yum-yum-cafe-seattle-2',
#    'name': 'Yum Yum Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rfJ7sf_OFzlVMRUEIXk1GQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yum-yum-cafe-seattle-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 20,
#    'categories': [{'alias': 'cantonese', 'title': 'Cantonese'},
#     {'alias': 'hkcafe', 'title': 'Hong Kong Style Cafe'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.50543, 'longitude': -122.33326},
#    'transactions': ['delivery'],
#    'location': {'address1': '10850 Myers Way S',
#     'address2': None,
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98168',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['10850 Myers Way S', 'Seattle, WA 98168']},
#    'phone': '+12062416054',
#    'display_phone': '(206) 241-6054',
#    'distance': 13353.241955595582},
#   {'id': 'DzLycxXa20wdlYeTcyc5-A',
#    'alias': 'dough-zone-dumpling-house-seattle-2',
#    'name': 'Dough Zone Dumpling House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tX5lR5jVME1ERDR7wSgmVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dough-zone-dumpling-house-seattle-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 887,
#    'categories': [{'alias': 'shanghainese', 'title': 'Shanghainese'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.59788, 'longitude': -122.32749},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '504 5th Ave S',
#     'address2': 'Ste 109',
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98104',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['504 5th Ave S', 'Ste 109', 'Seattle, WA 98104']},
#    'phone': '+12062859999',
#    'display_phone': '(206) 285-9999',
#    'distance': 3120.660721815892},
#   {'id': 'rXbU5HJx6mihqazytPTgXA',
#    'alias': 'kedai-makan-seattle-4',
#    'name': 'Kedai Makan',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PMqIAYAknTK01diJEspDOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kedai-makan-seattle-4?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 843,
#    'categories': [{'alias': 'malaysian', 'title': 'Malaysian'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 47.6179, 'longitude': -122.32658},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1802 Bellevue Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98122',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['1802 Bellevue Ave', 'Seattle, WA 98122']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1073.0051178890512},
#   {'id': 'pP5_BKZGvUjKglNIMfIGKg',
#    'alias': 'luosifen-seattle',
#    'name': 'LuoSiFen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LTUi8ob5C0kLiJ3Z4Kn98g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/luosifen-seattle?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 34,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.598595, 'longitude': -122.32716833},
#    'transactions': [],
#    'location': {'address1': '514 S King St',
#     'address2': '',
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98104',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['514 S King St', 'Seattle, WA 98104']},
#    'phone': '+12064857189',
#    'display_phone': '(206) 485-7189',
#    'distance': 3063.31972119006},
#   {'id': 'WXFQ9OHM4Q_lBtgPZEHttg',
#    'alias': 'charlala-hong-kong-café-and-hair-studio-seattle',
#    'name': 'Charlala Hong Kong Café and Hair Studio',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RidyVTsjltHUxeid8Dr4VA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/charlala-hong-kong-caf%C3%A9-and-hair-studio-seattle?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 63,
#    'categories': [{'alias': 'hkcafe', 'title': 'Hong Kong Style Cafe'},
#     {'alias': 'hair', 'title': 'Hair Salons'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 47.6652376541635,
#     'longitude': -122.317172326148},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1000 NE 50th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98105',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['1000 NE 50th St', 'Seattle, WA 98105']},
#    'phone': '+12067172970',
#    'display_phone': '(206) 717-2970',
#    'distance': 4635.846342945653},
#   {'id': 'l6dwcgNyn-ROwguZd-46fA',
#    'alias': 'chuan-bbq-seattle-7',
#    'name': 'Chuan BBQ',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RYytKKjpLqi2Xzk2r1-spA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chuan-bbq-seattle-7?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 126,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 47.68527, 'longitude': -122.34412},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '7714 Aurora Ave N',
#     'address2': None,
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98103',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['7714 Aurora Ave N', 'Seattle, WA 98103']},
#    'phone': '+12064540389',
#    'display_phone': '(206) 454-0389',
#    'distance': 6688.648829623034},
#   {'id': '0zyWCjmU4q3D2YJzJUULqA',
#    'alias': 'gourmet-noodle-bowl-seattle',
#    'name': 'Gourmet Noodle Bowl',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3_CjUql7GSOlgOhbTrW2CQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gourmet-noodle-bowl-seattle?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 399,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'taiwanese', 'title': 'Taiwanese'},
#     {'alias': 'hotpot', 'title': 'Hot Pot'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.596323, 'longitude': -122.322679},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '707 8th Ave S',
#     'address2': '',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98104',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['707 8th Ave S', 'Seattle, WA 98104']},
#    'phone': '+12062648899',
#    'display_phone': '(206) 264-8899',
#    'distance': 3375.286129090017},
#   {'id': 'cDHEx-LjtJRznSKJb0hR4Q',
#    'alias': 'buerjia-chinese-sauerkraut-fish-seattle-2',
#    'name': 'Buerjia Chinese Sauerkraut Fish',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1ojwDeRSC9_mOVbFA4Boew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/buerjia-chinese-sauerkraut-fish-seattle-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 25,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 47.66166, 'longitude': -122.31345},
#    'transactions': [],
#    'location': {'address1': '4509 University Way NE',
#     'address2': None,
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98105',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['4509 University Way NE', 'Seattle, WA 98105']},
#    'phone': '+12069466562',
#    'display_phone': '(206) 946-6562',
#    'distance': 4355.908488458346},
#   {'id': '_3wrETt6P6f41qZUYCu76w',
#    'alias': 'gan-bei-seattle',
#    'name': 'Gan Bei',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0ijp5XXVgLZifOsIGGD28Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gan-bei-seattle?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 40,
#    'categories': [{'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'hkcafe', 'title': 'Hong Kong Style Cafe'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 47.59768, 'longitude': -122.32413},
#    'transactions': [],
#    'location': {'address1': '670 S Weller St',
#     'address2': '',
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98104',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['670 S Weller St', 'Seattle, WA 98104']},
#    'phone': '+12066250408',
#    'display_phone': '(206) 625-0408',
#    'distance': 3199.6378729564653},
#   {'id': '8VsMux4zWPv48V1xbihszA',
#    'alias': 'fortune-garden-seattle',
#    'name': 'Fortune Garden',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MIqRHx26wR-G2Djws9Xthw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fortune-garden-seattle?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 143,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cantonese', 'title': 'Cantonese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.598489, 'longitude': -122.324868},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '424 Maynard Ave S',
#     'address2': '',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98104',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['424 Maynard Ave S', 'Seattle, WA 98104']},
#    'phone': '+12065218933',
#    'display_phone': '(206) 521-8933',
#    'distance': 3098.926152537826}],
#  'total': 873,
#  'region': {'center': {'longitude': -122.33551025390625,
#    'latitude': 47.62541904760501}}}

# %% [markdown]
# ## Pagination
#
# Now that you have an initial response, you can examine the contents of the JSON container. For example, you might start with ```response.json().keys()```. Here, you'll see a key for `'total'`, which tells you the full number of matching results given your query parameters. Write a loop (or ideally a function) which then makes successive API calls using the offset parameter to retrieve all of the results (or 5000 for a particularly large result set) for the original query. As you do this, be mindful of how you store the data. Your final goal will be to reformat the data concerning the businesses themselves into a pandas DataFrame from the json objects.
#
# **Note: be mindful of the API rate limits. You can only make 5000 requests per day and are also can make requests too fast. Start prototyping small before running a loop that could be faulty. You can also use time.sleep(n) to add delays. For more details see https://www.yelp.com/developers/documentation/v3/rate_limiting.**

# %%
json_response['total']
# Out:
# 873

# %%
url = 'https://api.yelp.com/v3/businesses/search'

def get_from_yelp_api(term, location, offset): #o offset
    SEARCH_LIMIT = offset
    
    df = pd.DataFrame()
    
    headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

    url_params = {
        'term': term.replace(' ', '+'),
        'location': location.replace(' ', '+'),
        'limit': SEARCH_LIMIT
    }
    
    while offset < 873:
        response = requests.get(url, headers=headers, params=url_params)
        
        #Throw response into dataframe
        
    return df
        

client_id = 'bVX1Jsfp4dkIOqw5HOVplg'
api_key = 'RTzp-q-TgkJW_NFQogubFvZNRDziXyoR38VbtZMWibDI-FlvB25OE7GmafFEqhTL8_Bk2HlcX24-hRWLMP7Nc6WHO_VXMXldpPBjP0LoPv5EFFELMSI2oll8njhbXHYx'

term = 'pizza'
location = 'ny'
SEARCH_LIMIT = 10

headers = {
    'Authorization': 'Bearer {}'.format(api_key),
}

url_params = {
    'term': term.replace(' ', '+'),
    'location': location.replace(' ', '+'),
    'limit': SEARCH_LIMIT
}

response = requests.get(url, headers=headers, params=url_params)

json_response = response.json()
json_response

# %% [markdown]
# ## Exploratory Analysis
#
# Take the restaurants from the previous question and do an initial exploratory analysis. At minimum, this should include looking at the distribution of features such as price, rating and number of reviews as well as the relations between these dimensions.

# %%
# Your code here

# %% [markdown]
# ## Mapping
#
# Look at the initial Yelp example and try and make a map using Folium of the restaurants you retrieved. Be sure to also add popups to the markers giving some basic information such as name, rating and price.

# %%
# Your code here

# %% [markdown]
# ## Summary
#
# Nice work! In this lab, you've made multiple API calls to Yelp in order to paginate through a results set, performing some basic exploratory analysis and then creating a nice interactive map to display the results using Folium! Well done!
